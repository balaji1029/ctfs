# %%
def gcd(a, b):
    if b == 0:
        return a
    return gcd(b, a % b)

gcd(12, 8)
gcd(66528, 52920)
# Out:
# 1512

# %%
p = 26513
q = 32321
gcd(p, q)
# Out:
# 1

# %%
def ext_euc(p, q):
    # p = q * a + b
    # q * u' + b * v' = gcd(p, q)
    # q * u' + (p - q * a) * v' = gcd(p, q)
    # p * v' + q * (u' - a * v') = gcd(p, q)
    if q == 0:
        return (1, 0, p)
    u, v, g = ext_euc(q, p % q)
    return (v, u - (p // q) * v, g)

# %%
ext_euc(p, q)
# Out:
# (10245, -8404, 1)

# %%
8146798528947 % 17
# Out:
# 4

# %%
p = 29
ints = [14, 6, 11]
for i in ints:
    for x in range(1, p):
        if (x * x) % p == i:
            print(x, i)
# Out:
# 8 6
# 21 6

# %%
p = 

ints = [, , , , , , , , , ]

# %%
for num in ints:
    if pow(num, (p - 1) // 2, p) == 1:
        x = num

# %%
pow(x, (p + 1) // 4, p)
# Out:
# 

# %%
a = ...
p = ...

# %%
#!/usr/bin/env python3

from pwn import * # pip install pwntools
import json

HOST = "socket.cryptohack.org"
PORT = 11112

r = remote(HOST, PORT)


def json_recv():
    line = r.readline()
    return json.loads(line.decode())

def json_send(hsh):
    request = json.dumps(hsh).encode()
    r.sendline(request)


print(r.readline())
print(r.readline())
print(r.readline())
print(r.readline())

request = {
    "buy": "flag"
}
json_send(request)

response = json_recv()

print(response)
# Out:
# [x] Opening connection to socket.cryptohack.org on port 11112
# [x] Opening connection to socket.cryptohack.org on port 11112: Trying 134.122.111.232
# [+] Opening connection to socket.cryptohack.org on port 11112: Done
# b"Welcome to netcat's flag shop!\n"
# b'What would you like to buy?\n'
# b"I only speak JSON, I hope that's ok.\n"
# b'\n'
# {'flag': 'crypto{sh0pp1ng_f0r_fl4g5}'}

# %%
#!/usr/bin/env python3

from Crypto.Util.number import bytes_to_long, long_to_bytes
from utils import listener # this is cryptohack's server-side module and not part of python
import base64
import codecs
import random

FLAG = "crypto{????????????????????}"
ENCODINGS = [
    "base64",
    "hex",
    "rot13",
    "bigint",
    "utf-8",
]
with open('/usr/share/dict/words') as f:
    WORDS = [line.strip().replace("'", "") for line in f.readlines()]


class Challenge():
    def __init__(self):
        self.challenge_words = ""
        self.stage = 0

    def create_level(self):
        self.stage += 1
        self.challenge_words = "_".join(random.choices(WORDS, k=3))
        encoding = random.choice(ENCODINGS)

        if encoding == "base64":
            encoded = base64.b64encode(self.challenge_words.encode()).decode() # wow so encode
        elif encoding == "hex":
            encoded = self.challenge_words.encode().hex()
        elif encoding == "rot13":
            encoded = codecs.encode(self.challenge_words, 'rot_13')
        elif encoding == "bigint":
            encoded = hex(bytes_to_long(self.challenge_words.encode()))
        elif encoding == "utf-8":
            encoded = [ord(b) for b in self.challenge_words]

        return {"type": encoding, "encoded": encoded}

    #
    # This challenge function is called on your input, which must be JSON
    # encoded
    #
    def challenge(self, your_input):
        if self.stage == 0:
            return self.create_level()
        elif self.stage == 100:
            self.exit = True
            return {"flag": FLAG}

        if self.challenge_words == your_input["decoded"]:
            return self.create_level()

        return {"error": "Decoding fail"}


listener.start_server(port=13377)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_7182/749437300.py in <module>
#       2
#       3 from Crypto.Util.number import bytes_to_long, long_to_bytes
# ----> 4 from utils import listener # this is cryptohack's server-side module and not part of python
#       5 import base64
#       6 import codecs
#
# ModuleNotFoundError: No module named 'utils'

# %%
from pwn import * # pip install pwntools
import json

def rot13(text):
    result = []
    for char in text:
        if 'a' <= char <= 'z':
            result.append(chr((ord(char) - ord('a') + 13) % 26 + ord('a')))
        elif 'A' <= char <= 'Z':
            result.append(chr((ord(char) - ord('A') + 13) % 26 + ord('A')))
        else:
            result.append(char)
    return ''.join(result)

r = remote('socket.cryptohack.org', 13377, level = 'debug')

def json_recv():
    line = r.recvline()
    return json.loads(line.decode())

def json_send(hsh):
    request = json.dumps(hsh).encode()
    r.sendline(request)

while True:
    received = json_recv()

    print("Received type: ")
    print(received["type"])
    print("Received encoded value: ")
    print(received["encoded"])

    if received["type"] == "base64":
        decoded = base64.b64decode(received["encoded"]).decode('utf-8')
    elif received["type"] == "hex":
        decoded = bytes.fromhex(received["encoded"]).decode('utf-8')
    elif received["type"] == "rot13":
        decoded = rot13(received["encoded"])
    elif received["type"] == "bigint":
        decoded = long_to_bytes(int(received["encoded"], 16)).decode('utf-8')
    elif received["type"] == "utf-8":
        decoded = "".join([chr(i) for i in received["encoded"]])

    to_send = {
        "decoded": decoded
    }
    json_send(to_send)    
    if "flag" in received:
        break
# Out:
# [x] Opening connection to socket.cryptohack.org on port 13377
# [x] Opening connection to socket.cryptohack.org on port 13377: Trying 134.122.111.232
# [+] Opening connection to socket.cryptohack.org on port 13377: Done
# [DEBUG] Received 0x3c bytes:
#     b'{"type": "rot13", "encoded": "rkcrevzragny_obbxvatf_vendv"}\n'
# Received type:
# rot13
# Received encoded value:
# rkcrevzragny_obbxvatf_vendv
# [DEBUG] Sent 0x2b bytes:
#     b'{"decoded": "experimental_bookings_iraqi"}\n'
# [DEBUG] Received 0x50 bytes:
#     b'{"type": "bigint", "encoded": "0x726576656e7565735f66616369616c5f77696c736f6e"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x726576656e7565735f66616369616c5f77696c736f6e
# [DEBUG] Sent 0x26 bytes:
#     b'{"decoded": "revenues_facial_wilson"}\n'
# [DEBUG] Received 0x4f bytes:
#     b'{"type": "hex", "encoded": "686973746f7269635f62726f77736572735f747265617479"}\n'
# Received type:
# hex
# Received encoded value:
# 686973746f7269635f62726f77736572735f747265617479
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "historic_browsers_treaty"}\n'
# [DEBUG] Received 0x36 bytes:
#     b'{"type": "rot13", "encoded": "iraqbe_frpherq_wbvarq"}\n'
# Received type:
# rot13
# Received encoded value:
# iraqbe_frpherq_wbvarq
# [DEBUG] Sent 0x25 bytes:
#     b'{"decoded": "vendor_secured_joined"}\n'
# [DEBUG] Received 0x42 bytes:
#     b'{"type": "base64", "encoded": "Y2VsdGljX2NlcnRpZmllZF9yb21hbg=="}\n'
# Received type:
# base64
# Received encoded value:
# Y2VsdGljX2NlcnRpZmllZF9yb21hbg==
# [DEBUG] Sent 0x26 bytes:
#     b'{"decoded": "celtic_certified_roman"}\n'
# [DEBUG] Received 0x32 bytes:
#     b'{"type": "rot13", "encoded": "zg_jverf_rcvavbaf"}\n'
# Received type:
# rot13
# Received encoded value:
# zg_jverf_rcvavbaf
# [DEBUG] Sent 0x21 bytes:
#     b'{"decoded": "mt_wires_epinions"}\n'
# [DEBUG] Received 0x35 bytes:
#     b'{"type": "rot13", "encoded": "snibhevgr_fgrry_ubbx"}\n'
# Received type:
# rot13
# Received encoded value:
# snibhevgr_fgrry_ubbx
# [DEBUG] Sent 0x24 bytes:
#     b'{"decoded": "favourite_steel_hook"}\n'
# [DEBUG] Received 0x46 bytes:
#     b'{"type": "base64", "encoded": "bXNnc3RyX2RhdWdodGVyX25hbWVzcGFjZQ=="}\n'
# Received type:
# base64
# Received encoded value:
# bXNnc3RyX2RhdWdodGVyX25hbWVzcGFjZQ==
# [DEBUG] Sent 0x29 bytes:
#     b'{"decoded": "msgstr_daughter_namespace"}\n'
# [DEBUG] Received 0x3e bytes:
#     b'{"type": "base64", "encoded": "bWV0cmVzX2FsYmFueV9mYXNoaW9u"}\n'
# Received type:
# base64
# Received encoded value:
# bWV0cmVzX2FsYmFueV9mYXNoaW9u
# [DEBUG] Sent 0x25 bytes:
#     b'{"decoded": "metres_albany_fashion"}\n'
# [DEBUG] Received 0x37 bytes:
#     b'{"type": "rot13", "encoded": "cebsrffvba_sbeg_yhkhel"}\n'
# Received type:
# rot13
# Received encoded value:
# cebsrffvba_sbeg_yhkhel
# [DEBUG] Sent 0x26 bytes:
#     b'{"decoded": "profession_fort_luxury"}\n'
# [DEBUG] Received 0x39 bytes:
#     b'{"type": "rot13", "encoded": "rfgnoyvfuvat_zrz_tenzzne"}\n'
# Received type:
# rot13
# Received encoded value:
# rfgnoyvfuvat_zrz_tenzzne
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "establishing_mem_grammar"}\n'
# [DEBUG] Received 0x4d bytes:
#     b'{"type": "hex", "encoded": "726576697365645f67726f7774685f61766f6964696e67"}\n'
# Received type:
# hex
# Received encoded value:
# 726576697365645f67726f7774685f61766f6964696e67
# [DEBUG] Sent 0x27 bytes:
#     b'{"decoded": "revised_growth_avoiding"}\n'
# [DEBUG] Received 0x3e bytes:
#     b'{"type": "base64", "encoded": "ZmFjaW5nX3N1Y2hfYWJhbmRvbmVk"}\n'
# Received type:
# base64
# Received encoded value:
# ZmFjaW5nX3N1Y2hfYWJhbmRvbmVk
# [DEBUG] Sent 0x25 bytes:
#     b'{"decoded": "facing_such_abandoned"}\n'
# [DEBUG] Received 0x8d bytes:
#     b'{"type": "utf-8", "encoded": [97, 112, 112, 101, 97, 114, 97, 110, 99, 101, 95, 114, 97, 99, 101, 115, 95, 115, 117, 114, 102, 97, 99, 101]}\n'
# Received type:
# utf-8
# Received encoded value:
# [97, 112, 112, 101, 97, 114, 97, 110, 99, 101, 95, 114, 97, 99, 101, 115, 95, 115, 117, 114, 102, 97, 99, 101]
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "appearance_races_surface"}\n'
# [DEBUG] Received 0x91 bytes:
#     b'{"type": "utf-8", "encoded": [109, 97, 116, 105, 110, 103, 95, 112, 111, 108, 97, 110, 100, 95, 99, 97, 114, 116, 114, 105, 100, 103, 101, 115]}\n'
# Received type:
# utf-8
# Received encoded value:
# [109, 97, 116, 105, 110, 103, 95, 112, 111, 108, 97, 110, 100, 95, 99, 97, 114, 116, 114, 105, 100, 103, 101, 115]
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "mating_poland_cartridges"}\n'
# [DEBUG] Received 0xaf bytes:
#     b'{"type": "utf-8", "encoded": [101, 120, 112, 114, 101, 115, 115, 105, 111, 110, 95, 99, 108, 97, 115, 115, 105, 102, 105, 99, 97, 116, 105, 111, 110, 95, 117, 110, 105, 116]}\n'
# Received type:
# utf-8
# Received encoded value:
# [101, 120, 112, 114, 101, 115, 115, 105, 111, 110, 95, 99, 108, 97, 115, 115, 105, 102, 105, 99, 97, 116, 105, 111, 110, 95, 117, 110, 105, 116]
# [DEBUG] Sent 0x2e bytes:
#     b'{"decoded": "expression_classification_unit"}\n'
# [DEBUG] Received 0x45 bytes:
#     b'{"type": "hex", "encoded": "6661756c745f62635f636f6e76656e69656e74"}\n'
# Received type:
# hex
# Received encoded value:
# 6661756c745f62635f636f6e76656e69656e74
# [DEBUG] Sent 0x23 bytes:
#     b'{"decoded": "fault_bc_convenient"}\n'
# [DEBUG] Received 0x7f bytes:
#     b'{"type": "utf-8", "encoded": [100, 111, 117, 103, 108, 97, 115, 95, 109, 111, 111, 114, 101, 95, 114, 97, 114, 101, 108, 121]}\n'
# Received type:
# utf-8
# Received encoded value:
# [100, 111, 117, 103, 108, 97, 115, 95, 109, 111, 111, 114, 101, 95, 114, 97, 114, 101, 108, 121]
# [DEBUG] Sent 0x24 bytes:
#     b'{"decoded": "douglas_moore_rarely"}\n'
# [DEBUG] Received 0x42 bytes:
#     b'{"type": "base64", "encoded": "a2lja19jb2xsYWJvcmF0aXZlX2Nsb3Ro"}\n'
# Received type:
# base64
# Received encoded value:
# a2lja19jb2xsYWJvcmF0aXZlX2Nsb3Ro
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "kick_collaborative_cloth"}\n'
# [DEBUG] Received 0x3e bytes:
#     b'{"type": "base64", "encoded": "dHJpbml0eV9maW5hbGx5X2VuZA=="}\n'
# Received type:
# base64
# Received encoded value:
# dHJpbml0eV9maW5hbGx5X2VuZA==
# [DEBUG] Sent 0x23 bytes:
#     b'{"decoded": "trinity_finally_end"}\n'
# [DEBUG] Received 0x52 bytes:
#     b'{"type": "bigint", "encoded": "0x686f6c6d65735f776172645f70726f6772616d6d657273"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x686f6c6d65735f776172645f70726f6772616d6d657273
# [DEBUG] Sent 0x27 bytes:
#     b'{"decoded": "holmes_ward_programmers"}\n'
# [DEBUG] Received 0x41 bytes:
#     b'{"type": "hex", "encoded": "636c7562735f7072696e746572735f6c6c"}\n'
# Received type:
# hex
# Received encoded value:
# 636c7562735f7072696e746572735f6c6c
# [DEBUG] Sent 0x21 bytes:
#     b'{"decoded": "clubs_printers_ll"}\n'
# [DEBUG] Received 0x3d bytes:
#     b'{"type": "hex", "encoded": "63685f62616c6c6f745f73706c6974"}\n'
# Received type:
# hex
# Received encoded value:
# 63685f62616c6c6f745f73706c6974
# [DEBUG] Sent 0x1f bytes:
#     b'{"decoded": "ch_ballot_split"}\n'
# [DEBUG] Received 0x58 bytes:
#     b'{"type": "bigint", "encoded": "0x6f726967696e735f636c6f7365725f64656d6f6e737472617465"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x6f726967696e735f636c6f7365725f64656d6f6e737472617465
# [DEBUG] Sent 0x2a bytes:
#     b'{"decoded": "origins_closer_demonstrate"}\n'
# [DEBUG] Received 0x31 bytes:
#     b'{"type": "rot13", "encoded": "xrvgu_vp_ercyvrq"}\n'
# Received type:
# rot13
# Received encoded value:
# xrvgu_vp_ercyvrq
# [DEBUG] Sent 0x20 bytes:
#     b'{"decoded": "keith_ic_replied"}\n'
# [DEBUG] Received 0x49 bytes:
#     b'{"type": "hex", "encoded": "666163746f725f72696e67746f6e65735f64617368"}\n'
# Received type:
# hex
# Received encoded value:
# 666163746f725f72696e67746f6e65735f64617368
# [DEBUG] Sent 0x25 bytes:
#     b'{"decoded": "factor_ringtones_dash"}\n'
# [DEBUG] Received 0x33 bytes:
#     b'{"type": "rot13", "encoded": "gvz_robbxf_irffryf"}\n'
# Received type:
# rot13
# Received encoded value:
# gvz_robbxf_irffryf
# [DEBUG] Sent 0x22 bytes:
#     b'{"decoded": "tim_ebooks_vessels"}\n'
# [DEBUG] Received 0x4c bytes:
#     b'{"type": "bigint", "encoded": "0x6368656174735f676f6e655f737570706c696572"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x6368656174735f676f6e655f737570706c696572
# [DEBUG] Sent 0x24 bytes:
#     b'{"decoded": "cheats_gone_supplier"}\n'
# [DEBUG] Received 0x49 bytes:
#     b'{"type": "hex", "encoded": "62687574616e5f736176696e67735f6d6f6d656e74"}\n'
# Received type:
# hex
# Received encoded value:
# 62687574616e5f736176696e67735f6d6f6d656e74
# [DEBUG] Sent 0x25 bytes:
#     b'{"decoded": "bhutan_savings_moment"}\n'
# [DEBUG] Received 0x40 bytes:
#     b'{"type": "rot13", "encoded": "pbafhzcgvba_snphygl_pbawhapgvba"}\n'
# Received type:
# rot13
# Received encoded value:
# pbafhzcgvba_snphygl_pbawhapgvba
# [DEBUG] Sent 0x2f bytes:
#     b'{"decoded": "consumption_faculty_conjunction"}\n'
# [DEBUG] Received 0x39 bytes:
#     b'{"type": "rot13", "encoded": "rssrpgvirarff_ica_znevba"}\n'
# Received type:
# rot13
# Received encoded value:
# rssrpgvirarff_ica_znevba
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "effectiveness_vpn_marion"}\n'
# [DEBUG] Received 0xbb bytes:
#     b'{"type": "utf-8", "encoded": [112, 114, 105, 110, 99, 101, 116, 111, 110, 95, 106, 111, 117, 114, 110, 97, 108, 105, 115, 116, 115, 95, 108, 105, 107, 101, 108, 105, 104, 111, 111, 100]}\n'
# Received type:
# utf-8
# Received encoded value:
# [112, 114, 105, 110, 99, 101, 116, 111, 110, 95, 106, 111, 117, 114, 110, 97, 108, 105, 115, 116, 115, 95, 108, 105, 107, 101, 108, 105, 104, 111, 111, 100]
# [DEBUG] Sent 0x30 bytes:
#     b'{"decoded": "princeton_journalists_likelihood"}\n'
# [DEBUG] Received 0x6e bytes:
#     b'{"type": "utf-8", "encoded": [99, 111, 119, 98, 111, 121, 95, 102, 97, 99, 116, 95, 108, 105, 110, 117, 120]}\n'
# Received type:
# utf-8
# Received encoded value:
# [99, 111, 119, 98, 111, 121, 95, 102, 97, 99, 116, 95, 108, 105, 110, 117, 120]
# [DEBUG] Sent 0x21 bytes:
#     b'{"decoded": "cowboy_fact_linux"}\n'
# [DEBUG] Received 0x5e bytes:
#     b'{"type": "bigint", "encoded": "0x7370656369666965735f73686570686572645f64657072657373696f6e"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x7370656369666965735f73686570686572645f64657072657373696f6e
# [DEBUG] Sent 0x2d bytes:
#     b'{"decoded": "specifies_shepherd_depression"}\n'
# [DEBUG] Received 0x92 bytes:
#     b'{"type": "utf-8", "encoded": [101, 110, 99, 111, 117, 114, 97, 103, 101, 95, 101, 120, 97, 109, 105, 110, 101, 95, 112, 117, 108, 108, 101, 100]}\n'
# Received type:
# utf-8
# Received encoded value:
# [101, 110, 99, 111, 117, 114, 97, 103, 101, 95, 101, 120, 97, 109, 105, 110, 101, 95, 112, 117, 108, 108, 101, 100]
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "encourage_examine_pulled"}\n'
# [DEBUG] Received 0x36 bytes:
#     b'{"type": "rot13", "encoded": "zvqavtug_obbxf_pnapre"}\n'
# Received type:
# rot13
# Received encoded value:
# zvqavtug_obbxf_pnapre
# [DEBUG] Sent 0x25 bytes:
#     b'{"decoded": "midnight_books_cancer"}\n'
# [DEBUG] Received 0x4d bytes:
#     b'{"type": "hex", "encoded": "7072656669785f6e61736876696c6c655f707261677565"}\n'
# Received type:
# hex
# Received encoded value:
# 7072656669785f6e61736876696c6c655f707261677565
# [DEBUG] Sent 0x27 bytes:
#     b'{"decoded": "prefix_nashville_prague"}\n'
# [DEBUG] Received 0x52 bytes:
#     b'{"type": "bigint", "encoded": "0x6669726d776172655f62656e65666974735f77696e6473"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x6669726d776172655f62656e65666974735f77696e6473
# [DEBUG] Sent 0x27 bytes:
#     b'{"decoded": "firmware_benefits_winds"}\n'
# [DEBUG] Received 0x3a bytes:
#     b'{"type": "base64", "encoded": "cGlrZV9kZWxheV9mZWVkcw=="}\n'
# Received type:
# base64
# Received encoded value:
# cGlrZV9kZWxheV9mZWVkcw==
# [DEBUG] Sent 0x20 bytes:
#     b'{"decoded": "pike_delay_feeds"}\n'
# [DEBUG] Received 0x48 bytes:
#     b'{"type": "bigint", "encoded": "0x6372656174757265735f70757273655f7475"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x6372656174757265735f70757273655f7475
# [DEBUG] Sent 0x22 bytes:
#     b'{"decoded": "creatures_purse_tu"}\n'
# [DEBUG] Received 0x4e bytes:
#     b'{"type": "bigint", "encoded": "0x6d696768745f717565656e736c616e645f6974656d"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x6d696768745f717565656e736c616e645f6974656d
# [DEBUG] Sent 0x25 bytes:
#     b'{"decoded": "might_queensland_item"}\n'
# [DEBUG] Received 0x46 bytes:
#     b'{"type": "base64", "encoded": "cmV2aWV3c19mcmVpZ2h0X3BvcHVsYXRpb24="}\n'
# Received type:
# base64
# Received encoded value:
# cmV2aWV3c19mcmVpZ2h0X3BvcHVsYXRpb24=
# [DEBUG] Sent 0x2a bytes:
#     b'{"decoded": "reviews_freight_population"}\n'
# [DEBUG] Received 0x4a bytes:
#     b'{"type": "base64", "encoded": "cmVjZW50bHlfcGxheXN0YXRpb25fZGVsaWNpb3Vz"}\n'
# Received type:
# base64
# Received encoded value:
# cmVjZW50bHlfcGxheXN0YXRpb25fZGVsaWNpb3Vz
# [DEBUG] Sent 0x2e bytes:
#     b'{"decoded": "recently_playstation_delicious"}\n'
# [DEBUG] Received 0x45 bytes:
#     b'{"type": "hex", "encoded": "726563656970745f7461686f655f636f6c6f6e"}\n'
# Received type:
# hex
# Received encoded value:
# 726563656970745f7461686f655f636f6c6f6e
# [DEBUG] Sent 0x23 bytes:
#     b'{"decoded": "receipt_tahoe_colon"}\n'
# [DEBUG] Received 0x66 bytes:
#     b'{"type": "utf-8", "encoded": [114, 101, 116, 97, 105, 108, 95, 112, 108, 97, 110, 101, 95, 100, 109]}\n'
# Received type:
# utf-8
# Received encoded value:
# [114, 101, 116, 97, 105, 108, 95, 112, 108, 97, 110, 101, 95, 100, 109]
# [DEBUG] Sent 0x1f bytes:
#     b'{"decoded": "retail_plane_dm"}\n'
# [DEBUG] Received 0x3e bytes:
#     b'{"type": "base64", "encoded": "dXJnZW50X3ZpbGxhc19jaGVxdWU="}\n'
# Received type:
# base64
# Received encoded value:
# dXJnZW50X3ZpbGxhc19jaGVxdWU=
# [DEBUG] Sent 0x24 bytes:
#     b'{"decoded": "urgent_villas_cheque"}\n'
# [DEBUG] Received 0x7d bytes:
#     b'{"type": "utf-8", "encoded": [103, 97, 105, 110, 115, 95, 98, 97, 110, 107, 115, 95, 111, 114, 100, 105, 110, 97, 114, 121]}\n'
# Received type:
# utf-8
# Received encoded value:
# [103, 97, 105, 110, 115, 95, 98, 97, 110, 107, 115, 95, 111, 114, 100, 105, 110, 97, 114, 121]
# [DEBUG] Sent 0x24 bytes:
#     b'{"decoded": "gains_banks_ordinary"}\n'
# [DEBUG] Received 0x6a bytes:
#     b'{"type": "utf-8", "encoded": [102, 108, 97, 103, 95, 98, 101, 110, 122, 95, 103, 111, 116, 104, 105, 99]}\n'
# Received type:
# utf-8
# Received encoded value:
# [102, 108, 97, 103, 95, 98, 101, 110, 122, 95, 103, 111, 116, 104, 105, 99]
# [DEBUG] Sent 0x20 bytes:
#     b'{"decoded": "flag_benz_gothic"}\n'
# [DEBUG] Received 0xbb bytes:
#     b'{"type": "utf-8", "encoded": [104, 121, 112, 111, 116, 104, 101, 115, 105, 115, 95, 115, 112, 101, 99, 116, 97, 99, 117, 108, 97, 114, 95, 98, 97, 110, 107, 114, 117, 112, 116, 99, 121]}\n'
# Received type:
# utf-8
# Received encoded value:
# [104, 121, 112, 111, 116, 104, 101, 115, 105, 115, 95, 115, 112, 101, 99, 116, 97, 99, 117, 108, 97, 114, 95, 98, 97, 110, 107, 114, 117, 112, 116, 99, 121]
# [DEBUG] Sent 0x31 bytes:
#     b'{"decoded": "hypothesis_spectacular_bankruptcy"}\n'
# [DEBUG] Received 0x37 bytes:
#     b'{"type": "rot13", "encoded": "znqarff_zvavzvmr_pynen"}\n'
# Received type:
# rot13
# Received encoded value:
# znqarff_zvavzvmr_pynen
# [DEBUG] Sent 0x26 bytes:
#     b'{"decoded": "madness_minimize_clara"}\n'
# [DEBUG] Received 0x42 bytes:
#     b'{"type": "base64", "encoded": "cGVyaXBoZXJhbF93aGVuX2J1cmVhdQ=="}\n'
# Received type:
# base64
# Received encoded value:
# cGVyaXBoZXJhbF93aGVuX2J1cmVhdQ==
# [DEBUG] Sent 0x26 bytes:
#     b'{"decoded": "peripheral_when_bureau"}\n'
# [DEBUG] Received 0x34 bytes:
#     b'{"type": "rot13", "encoded": "eruno_robal_cnpxrgf"}\n'
# Received type:
# rot13
# Received encoded value:
# eruno_robal_cnpxrgf
# [DEBUG] Sent 0x23 bytes:
#     b'{"decoded": "rehab_ebony_packets"}\n'
# [DEBUG] Received 0x46 bytes:
#     b'{"type": "base64", "encoded": "dGhyb3dpbmdfY2Fubm9uX2NvbnRpbnVhbGx5"}\n'
# Received type:
# base64
# Received encoded value:
# dGhyb3dpbmdfY2Fubm9uX2NvbnRpbnVhbGx5
# [DEBUG] Sent 0x2b bytes:
#     b'{"decoded": "throwing_cannon_continually"}\n'
# [DEBUG] Received 0x3e bytes:
#     b'{"type": "base64", "encoded": "YnJva2VyX2ZhbGxfYXVjdGlvbnM="}\n'
# Received type:
# base64
# Received encoded value:
# YnJva2VyX2ZhbGxfYXVjdGlvbnM=
# [DEBUG] Sent 0x24 bytes:
#     b'{"decoded": "broker_fall_auctions"}\n'
# [DEBUG] Received 0x74 bytes:
#     b'{"type": "utf-8", "encoded": [102, 108, 97, 115, 104, 95, 108, 97, 117, 114, 97, 95, 108, 111, 118, 101, 114, 115]}\n'
# Received type:
# utf-8
# Received encoded value:
# [102, 108, 97, 115, 104, 95, 108, 97, 117, 114, 97, 95, 108, 111, 118, 101, 114, 115]
# [DEBUG] Sent 0x22 bytes:
#     b'{"decoded": "flash_laura_lovers"}\n'
# [DEBUG] Received 0x67 bytes:
#     b'{"type": "hex", "encoded": "6e65636573736974795f726570726f647563746976655f64657465726d696e6174696f6e"}\n'
# Received type:
# hex
# Received encoded value:
# 6e65636573736974795f726570726f647563746976655f64657465726d696e6174696f6e
# [DEBUG] Sent 0x34 bytes:
#     b'{"decoded": "necessity_reproductive_determination"}\n'
# [DEBUG] Received 0x41 bytes:
#     b'{"type": "hex", "encoded": "66726175645f6261636b5f626f78696e67"}\n'
# Received type:
# hex
# Received encoded value:
# 66726175645f6261636b5f626f78696e67
# [DEBUG] Sent 0x21 bytes:
#     b'{"decoded": "fraud_back_boxing"}\n'
# [DEBUG] Received 0x40 bytes:
#     b'{"type": "bigint", "encoded": "0x676f7370656c5f6475695f6c6f67"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x676f7370656c5f6475695f6c6f67
# [DEBUG] Sent 0x1e bytes:
#     b'{"decoded": "gospel_dui_log"}\n'
# [DEBUG] Received 0x53 bytes:
#     b'{"type": "hex", "encoded": "70616c657374696e69616e5f696e63685f646576656c6f706564"}\n'
# Received type:
# hex
# Received encoded value:
# 70616c657374696e69616e5f696e63685f646576656c6f706564
# [DEBUG] Sent 0x2a bytes:
#     b'{"decoded": "palestinian_inch_developed"}\n'
# [DEBUG] Received 0x4f bytes:
#     b'{"type": "hex", "encoded": "7368616e6e6f6e5f74726962616c5f70686f746f73686f70"}\n'
# Received type:
# hex
# Received encoded value:
# 7368616e6e6f6e5f74726962616c5f70686f746f73686f70
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "shannon_tribal_photoshop"}\n'
# [DEBUG] Received 0x4a bytes:
#     b'{"type": "bigint", "encoded": "0x6d73675f686173685f696e74726f6475636564"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x6d73675f686173685f696e74726f6475636564
# [DEBUG] Sent 0x23 bytes:
#     b'{"decoded": "msg_hash_introduced"}\n'
# [DEBUG] Received 0x3e bytes:
#     b'{"type": "base64", "encoded": "YXJtZW5pYV9ob2xtZXNfd2lsbG93"}\n'
# Received type:
# base64
# Received encoded value:
# YXJtZW5pYV9ob2xtZXNfd2lsbG93
# [DEBUG] Sent 0x25 bytes:
#     b'{"decoded": "armenia_holmes_willow"}\n'
# [DEBUG] Received 0x66 bytes:
#     b'{"type": "utf-8", "encoded": [100, 114, 111, 112, 95, 99, 111, 114, 112, 95, 97, 100, 109, 105, 116]}\n'
# Received type:
# utf-8
# Received encoded value:
# [100, 114, 111, 112, 95, 99, 111, 114, 112, 95, 97, 100, 109, 105, 116]
# [DEBUG] Sent 0x1f bytes:
#     b'{"decoded": "drop_corp_admit"}\n'
# [DEBUG] Received 0x31 bytes:
#     b'{"type": "rot13", "encoded": "bnxf_bqqf_hayrff"}\n'
# Received type:
# rot13
# Received encoded value:
# bnxf_bqqf_hayrff
# [DEBUG] Sent 0x20 bytes:
#     b'{"decoded": "oaks_odds_unless"}\n'
# [DEBUG] Received 0xc6 bytes:
#     b'{"type": "utf-8", "encoded": [105, 110, 116, 101, 114, 110, 97, 116, 105, 111, 110, 97, 108, 108, 121, 95, 97, 109, 101, 110, 100, 109, 101, 110, 116, 115, 95, 97, 100, 118, 111, 99, 97, 116, 101]}\n'
# Received type:
# utf-8
# Received encoded value:
# [105, 110, 116, 101, 114, 110, 97, 116, 105, 111, 110, 97, 108, 108, 121, 95, 97, 109, 101, 110, 100, 109, 101, 110, 116, 115, 95, 97, 100, 118, 111, 99, 97, 116, 101]
# [DEBUG] Sent 0x33 bytes:
#     b'{"decoded": "internationally_amendments_advocate"}\n'
# [DEBUG] Received 0x7c bytes:
#     b'{"type": "utf-8", "encoded": [106, 111, 107, 101, 95, 102, 114, 101, 101, 122, 101, 95, 105, 109, 112, 108, 105, 101, 100]}\n'
# Received type:
# utf-8
# Received encoded value:
# [106, 111, 107, 101, 95, 102, 114, 101, 101, 122, 101, 95, 105, 109, 112, 108, 105, 101, 100]
# [DEBUG] Sent 0x23 bytes:
#     b'{"decoded": "joke_freeze_implied"}\n'
# [DEBUG] Received 0x48 bytes:
#     b'{"type": "bigint", "encoded": "0x6c696e655f7061727469636c655f66616b65"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x6c696e655f7061727469636c655f66616b65
# [DEBUG] Sent 0x22 bytes:
#     b'{"decoded": "line_particle_fake"}\n'
# [DEBUG] Received 0x42 bytes:
#     b'{"type": "base64", "encoded": "ZnVsbF9kZWZlbnNpdmVfcHV0dGluZw=="}\n'
# Received type:
# base64
# Received encoded value:
# ZnVsbF9kZWZlbnNpdmVfcHV0dGluZw==
# [DEBUG] Sent 0x26 bytes:
#     b'{"decoded": "full_defensive_putting"}\n'
# [DEBUG] Received 0x3e bytes:
#     b'{"type": "base64", "encoded": "Ymxvb2RfYWR2aXNlZF90b29sYm94"}\n'
# Received type:
# base64
# Received encoded value:
# Ymxvb2RfYWR2aXNlZF90b29sYm94
# [DEBUG] Sent 0x25 bytes:
#     b'{"decoded": "blood_advised_toolbox"}\n'
# [DEBUG] Received 0x8e bytes:
#     b'{"type": "utf-8", "encoded": [114, 101, 112, 114, 101, 115, 101, 110, 116, 95, 100, 114, 97, 109, 97, 95, 110, 101, 119, 112, 111, 114, 116]}\n'
# Received type:
# utf-8
# Received encoded value:
# [114, 101, 112, 114, 101, 115, 101, 110, 116, 95, 100, 114, 97, 109, 97, 95, 110, 101, 119, 112, 111, 114, 116]
# [DEBUG] Sent 0x27 bytes:
#     b'{"decoded": "represent_drama_newport"}\n'
# [DEBUG] Received 0x46 bytes:
#     b'{"type": "base64", "encoded": "cmVjb3Zlcl9hZ3JlZWRfZnVuZGFtZW50YWw="}\n'
# Received type:
# base64
# Received encoded value:
# cmVjb3Zlcl9hZ3JlZWRfZnVuZGFtZW50YWw=
# [DEBUG] Sent 0x2a bytes:
#     b'{"decoded": "recover_agreed_fundamental"}\n'
# [DEBUG] Received 0x5d bytes:
#     b'{"type": "utf-8", "encoded": [122, 111, 111, 109, 95, 112, 111, 112, 101, 95, 109, 97, 115]}\n'
# Received type:
# utf-8
# Received encoded value:
# [122, 111, 111, 109, 95, 112, 111, 112, 101, 95, 109, 97, 115]
# [DEBUG] Sent 0x1d bytes:
#     b'{"decoded": "zoom_pope_mas"}\n'
# [DEBUG] Received 0x92 bytes:
#     b'{"type": "utf-8", "encoded": [97, 100, 118, 97, 110, 116, 97, 103, 101, 95, 115, 117, 112, 101, 114, 105, 111, 114, 95, 102, 101, 119, 101, 114]}\n'
# Received type:
# utf-8
# Received encoded value:
# [97, 100, 118, 97, 110, 116, 97, 103, 101, 95, 115, 117, 112, 101, 114, 105, 111, 114, 95, 102, 101, 119, 101, 114]
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "advantage_superior_fewer"}\n'
# [DEBUG] Received 0xb0 bytes:
#     b'{"type": "utf-8", "encoded": [112, 114, 101, 102, 101, 114, 101, 110, 99, 101, 95, 115, 119, 105, 116, 122, 101, 114, 108, 97, 110, 100, 95, 115, 117, 109, 109, 97, 114, 121]}\n'
# Received type:
# utf-8
# Received encoded value:
# [112, 114, 101, 102, 101, 114, 101, 110, 99, 101, 95, 115, 119, 105, 116, 122, 101, 114, 108, 97, 110, 100, 95, 115, 117, 109, 109, 97, 114, 121]
# [DEBUG] Sent 0x2e bytes:
#     b'{"decoded": "preference_switzerland_summary"}\n'
# [DEBUG] Received 0x3a bytes:
#     b'{"type": "base64", "encoded": "YWxvbmdfcHJldmVudF9kb25l"}\n'
# Received type:
# base64
# Received encoded value:
# YWxvbmdfcHJldmVudF9kb25l
# [DEBUG] Sent 0x22 bytes:
#     b'{"decoded": "along_prevent_done"}\n'
# [DEBUG] Received 0x41 bytes:
#     b'{"type": "hex", "encoded": "73706963655f7068645f6b69746368656e"}\n'
# Received type:
# hex
# Received encoded value:
# 73706963655f7068645f6b69746368656e
# [DEBUG] Sent 0x21 bytes:
#     b'{"decoded": "spice_phd_kitchen"}\n'
# [DEBUG] Received 0x3b bytes:
#     b'{"type": "rot13", "encoded": "evpuzbaq_nygreangr_jvyyvat"}\n'
# Received type:
# rot13
# Received encoded value:
# evpuzbaq_nygreangr_jvyyvat
# [DEBUG] Sent 0x2a bytes:
#     b'{"decoded": "richmond_alternate_willing"}\n'
# [DEBUG] Received 0x3b bytes:
#     b'{"type": "hex", "encoded": "6c6c635f7669635f7277616e6461"}\n'
# Received type:
# hex
# Received encoded value:
# 6c6c635f7669635f7277616e6461
# [DEBUG] Sent 0x1e bytes:
#     b'{"decoded": "llc_vic_rwanda"}\n'
# [DEBUG] Received 0x39 bytes:
#     b'{"type": "rot13", "encoded": "fubegf_rffrapr_inevrgvrf"}\n'
# Received type:
# rot13
# Received encoded value:
# fubegf_rffrapr_inevrgvrf
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "shorts_essence_varieties"}\n'
# [DEBUG] Received 0x49 bytes:
#     b'{"type": "hex", "encoded": "63617061626c655f6272696768745f616d616e6461"}\n'
# Received type:
# hex
# Received encoded value:
# 63617061626c655f6272696768745f616d616e6461
# [DEBUG] Sent 0x25 bytes:
#     b'{"decoded": "capable_bright_amanda"}\n'
# [DEBUG] Received 0x41 bytes:
#     b'{"type": "hex", "encoded": "776973655f63616d65726f6e5f6b65656e"}\n'
# Received type:
# hex
# Received encoded value:
# 776973655f63616d65726f6e5f6b65656e
# [DEBUG] Sent 0x21 bytes:
#     b'{"decoded": "wise_cameron_keen"}\n'
# [DEBUG] Received 0x3a bytes:
#     b'{"type": "base64", "encoded": "eWFuZ19jYW1lbF9kYXZpcw=="}\n'
# Received type:
# base64
# Received encoded value:
# eWFuZ19jYW1lbF9kYXZpcw==
# [DEBUG] Sent 0x20 bytes:
#     b'{"decoded": "yang_camel_davis"}\n'
# [DEBUG] Received 0x58 bytes:
#     b'{"type": "bigint", "encoded": "0x76656765746174696f6e5f6d61696c735f656c656374696f6e73"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x76656765746174696f6e5f6d61696c735f656c656374696f6e73
# [DEBUG] Sent 0x2a bytes:
#     b'{"decoded": "vegetation_mails_elections"}\n'
# [DEBUG] Received 0x54 bytes:
#     b'{"type": "bigint", "encoded": "0x636869636b735f64657374696e795f70726f636564757265"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x636869636b735f64657374696e795f70726f636564757265
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "chicks_destiny_procedure"}\n'
# [DEBUG] Received 0x46 bytes:
#     b'{"type": "base64", "encoded": "c2NlbmFyaW9zX3ZlZ2V0YWJsZV9yYXBpZA=="}\n'
# Received type:
# base64
# Received encoded value:
# c2NlbmFyaW9zX3ZlZ2V0YWJsZV9yYXBpZA==
# [DEBUG] Sent 0x29 bytes:
#     b'{"decoded": "scenarios_vegetable_rapid"}\n'
# [DEBUG] Received 0x42 bytes:
#     b'{"type": "base64", "encoded": "aGVscGVkX3N1enVraV9icmluZ2luZw=="}\n'
# Received type:
# base64
# Received encoded value:
# aGVscGVkX3N1enVraV9icmluZ2luZw==
# [DEBUG] Sent 0x26 bytes:
#     b'{"decoded": "helped_suzuki_bringing"}\n'
# [DEBUG] Received 0x47 bytes:
#     b'{"type": "hex", "encoded": "6265666f72655f6373745f736861726577617265"}\n'
# Received type:
# hex
# Received encoded value:
# 6265666f72655f6373745f736861726577617265
# [DEBUG] Sent 0x24 bytes:
#     b'{"decoded": "before_cst_shareware"}\n'
# [DEBUG] Received 0x51 bytes:
#     b'{"type": "hex", "encoded": "617070656172616e63655f7061727469636c655f636c656172"}\n'
# Received type:
# hex
# Received encoded value:
# 617070656172616e63655f7061727469636c655f636c656172
# [DEBUG] Sent 0x29 bytes:
#     b'{"decoded": "appearance_particle_clear"}\n'
# [DEBUG] Received 0x83 bytes:
#     b'{"type": "utf-8", "encoded": [119, 105, 116, 104, 105, 110, 95, 115, 116, 97, 110, 100, 97, 114, 100, 95, 116, 97, 108, 107, 115]}\n'
# Received type:
# utf-8
# Received encoded value:
# [119, 105, 116, 104, 105, 110, 95, 115, 116, 97, 110, 100, 97, 114, 100, 95, 116, 97, 108, 107, 115]
# [DEBUG] Sent 0x25 bytes:
#     b'{"decoded": "within_standard_talks"}\n'
# [DEBUG] Received 0x4f bytes:
#     b'{"type": "hex", "encoded": "727574685f6772616475616c6c795f696e74657276696577"}\n'
# Received type:
# hex
# Received encoded value:
# 727574685f6772616475616c6c795f696e74657276696577
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "ruth_gradually_interview"}\n'
# [DEBUG] Received 0x70 bytes:
#     b'{"type": "utf-8", "encoded": [114, 97, 105, 110, 95, 101, 118, 101, 114, 95, 99, 111, 118, 101, 114, 101, 100]}\n'
# Received type:
# utf-8
# Received encoded value:
# [114, 97, 105, 110, 95, 101, 118, 101, 114, 95, 99, 111, 118, 101, 114, 101, 100]
# [DEBUG] Sent 0x21 bytes:
#     b'{"decoded": "rain_ever_covered"}\n'
# [DEBUG] Received 0x36 bytes:
#     b'{"type": "base64", "encoded": "c2F2ZV9oaXRfdGhvbmdz"}\n'
# Received type:
# base64
# Received encoded value:
# c2F2ZV9oaXRfdGhvbmdz
# [DEBUG] Sent 0x1f bytes:
#     b'{"decoded": "save_hit_thongs"}\n'
# [DEBUG] Received 0x7c bytes:
#     b'{"type": "utf-8", "encoded": [109, 97, 105, 110, 116, 101, 110, 97, 110, 99, 101, 95, 99, 108, 111, 115, 101, 95, 105, 99]}\n'
# Received type:
# utf-8
# Received encoded value:
# [109, 97, 105, 110, 116, 101, 110, 97, 110, 99, 101, 95, 99, 108, 111, 115, 101, 95, 105, 99]
# [DEBUG] Sent 0x24 bytes:
#     b'{"decoded": "maintenance_close_ic"}\n'
# [DEBUG] Received 0x9e bytes:
#     b'{"type": "utf-8", "encoded": [109, 105, 99, 114, 111, 112, 104, 111, 110, 101, 95, 119, 111, 114, 108, 100, 115, 95, 111, 112, 116, 105, 109, 105, 122, 101]}\n'
# Received type:
# utf-8
# Received encoded value:
# [109, 105, 99, 114, 111, 112, 104, 111, 110, 101, 95, 119, 111, 114, 108, 100, 115, 95, 111, 112, 116, 105, 109, 105, 122, 101]
# [DEBUG] Sent 0x2a bytes:
#     b'{"decoded": "microphone_worlds_optimize"}\n'
# [DEBUG] Received 0x54 bytes:
#     b'{"type": "bigint", "encoded": "0x646966666963756c74795f736563746f72735f6461697279"}\n'
# Received type:
# bigint
# Received encoded value:
# 0x646966666963756c74795f736563746f72735f6461697279
# [DEBUG] Sent 0x28 bytes:
#     b'{"decoded": "difficulty_sectors_dairy"}\n'
# [DEBUG] Received 0x3e bytes:
#     b'{"type": "base64", "encoded": "cGFuX3Bha2lzdGFuX3RyaXVtcGg="}\n'
# Received type:
# base64
# Received encoded value:
# cGFuX3Bha2lzdGFuX3RyaXVtcGg=
# [DEBUG] Sent 0x24 bytes:
#     b'{"decoded": "pan_pakistan_triumph"}\n'
# [DEBUG] Received 0x42 bytes:
#     b'{"type": "base64", "encoded": "ZGV1dHNjaF9waWVjZXNfc2VsZWN0ZWQ="}\n'
# Received type:
# base64
# Received encoded value:
# ZGV1dHNjaF9waWVjZXNfc2VsZWN0ZWQ=
# [DEBUG] Sent 0x27 bytes:
#     b'{"decoded": "deutsch_pieces_selected"}\n'
# [DEBUG] Received 0x46 bytes:
#     b'{"type": "base64", "encoded": "bWFyc19sYXVuZHJ5X21vZGlmaWNhdGlvbg=="}\n'
# Received type:
# base64
# Received encoded value:
# bWFyc19sYXVuZHJ5X21vZGlmaWNhdGlvbg==
# [DEBUG] Sent 0x29 bytes:
#     b'{"decoded": "mars_laundry_modification"}\n'
# [DEBUG] Received 0x33 bytes:
#     b'{"type": "rot13", "encoded": "jrysner_hygenz_rin"}\n'
# Received type:
# rot13
# Received encoded value:
# jrysner_hygenz_rin
# [DEBUG] Sent 0x22 bytes:
#     b'{"decoded": "welfare_ultram_eva"}\n'
# [DEBUG] Received 0x46 bytes:
#     b'{"type": "base64", "encoded": "Y2lyY3Vtc3RhbmNlc19pbnRlZ2VyX3RhYnM="}\n'
# Received type:
# base64
# Received encoded value:
# Y2lyY3Vtc3RhbmNlc19pbnRlZ2VyX3RhYnM=
# [DEBUG] Sent 0x2a bytes:
#     b'{"decoded": "circumstances_integer_tabs"}\n'
# [DEBUG] Received 0x29 bytes:
#     b'{"flag": "crypto{3nc0d3_d3c0d3_3nc0d3}"}\n'
# Received type:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_7182/656043472.py in <module>
#      27
#      28     print("Received type: ")
# ---> 29     print(received["type"])
#      30     print("Received encoded value: ")
#      31     print(received["encoded"])
#
# KeyError: 'type'
